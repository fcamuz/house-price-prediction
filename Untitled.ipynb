# %%
#import all necessary libraries.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(style='whitegrid')

# Modeling, Evaluation
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn import metrics
import statsmodels.api as sm

# Feature Selection
from sklearn.feature_selection import RFE
# Scaler
from sklearn.preprocessing import MinMaxScaler

import warnings

# Loading data into pandas DataFrame
df = pd.read_csv('kc_house_data.csv')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
df.waterfront=df['waterfront'].astype('category')

# %%
df.waterfront=df['waterfront'].cat.codes

# %%
waterfront= pd.get_dummies(df['waterfront'], prefix='wfr', drop_first=True)

# %%
df=df.join(waterfront)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 23 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       21597 non-null int8
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
plt.figure(figsize=(14,8))
sns.scatterplot(df.long, df.lat, hue=df.sqft_lot, size=df.sqft_lot, palette='tab20')
plt.xlim(-122.5, -121.7)
plt.title('Locations and Prices', fontdict={'fontsize': 20})
plt.show()

# %%
    
plt.figure(figsize=(12,12))
plt.ylim(0,250000)
sns.scatterplot(df.yr_built, df.sqft_lot)
sns.scatterplot(df.yr_built, df.sqft_living)

# %%
plt.figure(figsize=(12,12))
plt.ylim(0,250000)
plt.ylim(0,400000)
sns.scatterplot(df.price, df.sqft_lot)
sns.scatterplot(df.price, df.sqft_living)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
sns.scatterplot(df.yr_built, df.sqft_living)

# %%
sns.scatterplot(df.price, df.sqft_lot)

# %%
sns.scatterplot(df.price, df.sqft_living)

# %%
fig=plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# Tell pointplot to plot on ax1 with the ax argument
#sns.pointplot(x="x", y="y", data=data, ax=ax1)
sns.scatterplot(df.price, df.sqft_living, data=df, ax=ax1)

# Plot the errorbar directly on ax1
#ax1.errorbar(np.arange(len(data["x"])), data["y"], yerr=data["s"])

# Tell the factorplot to plot on ax2 with the ax argument
# Also store the FacetGrid in 'g'

g=sns.scatterplot(df.price, df.sqft_lot, data=df, ax=ax2)

# Close the FacetGrid figure which we don't need (g.fig)
plt.close(g.fig)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-069e5d4d4923> in <module>()
#      16
#      17 # Close the FacetGrid figure which we don't need (g.fig)
# ---> 18 plt.close(g.fig)
#      19
#      20 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'fig'

# %%
sns.scatterplot(df.sqft_living, df.sqft_lot)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

plt.figure(figsize=(12,12))
sns.lineplot(x="sqft_living", y="price",   data=df)
# Out:
# /Users/kaan/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
lotpercent=(df.sqft_living/df.sqft_lot)*100

# %%
plt.figure(figsize=(12,6))
sns.lineplot(df.sqft_lot15, df.price)
#plt.xlim(0, 200)
plt.ylim(0, 4000000)
# Out:
# /Users/kaan/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-67850b25fe6b> in <module>()
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.lineplot(df.sqft_lot15, df.price)
#       3 #plt.xlim(0, 200)
#       4 plt.ylim(0, 4000000)
#
# ...

# %%
"""plt.figure(figsize=(12,6))
sns.lineplot(df.yr_built, lotpercent)
#plt.xlim(0,400)"""
# Out:
# 'plt.figure(figsize=(12,6))\nsns.lineplot(df.yr_built, lotpercent)\n#plt.xlim(0,400)'

# %%
"""plt.figure(figsize=(14,8))
sns.scatterplot(df.long, df.lat, hue=lotpercent, size=lotpercent, palette='tab20')
plt.xlim(-122.5, -121.7)
plt.title('Locations and Prices', fontdict={'fontsize': 20})
plt.show()"""
# Out:
# "plt.figure(figsize=(14,8))\nsns.scatterplot(df.long, df.lat, hue=lotpercent, size=lotpercent, palette='tab20')\nplt.xlim(-122.5, -121.7)\nplt.title('Locations and Prices', fontdict={'fontsize': 20})\nplt.show()"

# %%
"""plt.figure(figsize=(14,8))
sns.scatterplot(df.long, df.lat, hue=df.price, size=df.price, palette='tab20')
plt.xlim(-122.5, -121.7)
plt.title('Locations and Prices', fontdict={'fontsize': 20})
plt.show()"""
# Out:
# "plt.figure(figsize=(14,8))\nsns.scatterplot(df.long, df.lat, hue=df.price, size=df.price, palette='tab20')\nplt.xlim(-122.5, -121.7)\nplt.title('Locations and Prices', fontdict={'fontsize': 20})\nplt.show()"

# %%
df.yr_renovated.value_counts()
# Out:
# 0.0       17011
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
# 2000.0       29
# 2005.0       29
# 1990.0       22
# 2004.0       22
# 2009.0       21
# 1989.0       20
# 2006.0       20
# 2002.0       17
# 1991.0       16
# 1998.0       16
# 1984.0       16
# 1999.0       15
# 2008.0       15
# 2010.0       15
# 2001.0       15
# 1983.0       15
# 2015.0       14
# 1985.0       14
# 1986.0       14
# 1987.0       14
# 1994.0       14
# 1992.0       13
# 1993.0       12
# 1997.0       12
# 1995.0       12
#           ...
# 1975.0        5
# 1964.0        5
# 1969.0        4
# 1963.0        4
# 1973.0        4
# 1981.0        4
# 1965.0        4
# 1978.0        3
# 1960.0        3
# 1958.0        3
# 1956.0        3
# 1955.0        3
# 1945.0        3
# 1972.0        3
# 1967.0        2
# 1957.0        2
# 1940.0        2
# 1974.0        2
# 1962.0        2
# 1953.0        1
# 1950.0        1
# 1934.0        1
# 1944.0        1
# 1976.0        1
# ...

# %%
sns.distplot(df.yr_renovated)
plt.title("Distribution of the yr_renovated values")
plt.xlabel("yr_renovated Values")
#plt.ylabel("# of Houses")
# Out:
# /Users/kaan/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/kaan/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# /Users/kaan/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

formula = 'price ~ sqft_living'
model = ols(formula = formula, data=df).fit()

#X_new = pd.DataFrame({val: [df_cont['sqft_living'].min(), df_cont['sqft_living'].max()]});
#preds = model.predict(X_new)

#model.summary()

# %%
import patsy

patsy.__version__
# Out:
# '0.5.1'
